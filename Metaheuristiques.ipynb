# %%
# %autoreload

import definitions
import model
import algorithm
import analysis

# %%
circuit = model.circuit.Circuit(5)
# %pylab inline
pylab.rcParams['figure.figsize'] = (6, 6)
circuit.plot(interval_ratio=1.1)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
circuit.calculate_configuration_length()
# Out:
# 200.0

# %%
circuit.perform_random_permutation()
# %pylab inline
pylab.rcParams['figure.figsize'] = (6, 6)
circuit.plot(interval_ratio=1.1)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
simulated_annealing = algorithm.simulated_annealing.SimulatedAnnealing()
simulated_annealing.initialise(5, 65456848146514531, 10.0)
circuit = simulated_annealing.run_algorithm(10000, True)
print(simulated_annealing.convergence[-1])
# Out:
# 238.9949493661166

# %%
simulated_annealing_convergence1 = analysis.simulated_annealing_convergence.SimulatedAnnealingConvergence()
simulated_annealing_convergence1.perform_simulation(5, 546854684354354, 10.0, 10000)

# %%
# %pylab inline
pylab.rcParams['figure.figsize'] = (10, 6)
simulated_annealing_convergence1.plot_convergence()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
simulated_annealing_convergence2 = analysis.simulated_annealing_convergence.SimulatedAnnealingConvergence()
simulated_annealing_convergence2.perform_multiple_simulations(5, 10.0, 10000, 100)

# %%
# %pylab inline
pylab.rcParams['figure.figsize'] = (10, 6)
simulated_annealing_convergence2.plot_multiple_convergence(axis_lim=[0, 10000, 150, 600])
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
simulated_annealing_convergence3 = analysis.simulated_annealing_convergence.SimulatedAnnealingConvergence()
simulated_annealing_convergence3.perform_multiple_simulations_initial_temperatures(5, [0.001, 0.01, 0.1, 1.0, 10.0, 100.0], 1000, 10)

# %%
# %pylab inline
pylab.rcParams['figure.figsize'] = (10, 6)
simulated_annealing_convergence3.plot_multiple_convergence_initial_temperatures()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
simulated_annealing_convergence4 = analysis.simulated_annealing_convergence.SimulatedAnnealingConvergence()
simulated_annealing_convergence4.perform_multiple_simulations_initial_temperatures(5, [0.001, 0.01, 0.1, 1.0, 10.0, 100.0], 10000, 10)

# %%
# %pylab inline
pylab.rcParams['figure.figsize'] = (10, 6)
simulated_annealing_convergence4.plot_multiple_convergence_initial_temperatures()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# %pylab inline
pylab.rcParams['figure.figsize'] = (10, 6)
simulated_annealing_convergence4.plot_best_multiple_convergence_initial_temperatures(2)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
simulated_annealing_convergence5 = analysis.simulated_annealing_convergence.SimulatedAnnealingConvergence()
simulated_annealing_convergence5.perform_simulation(5, 546854684354354, 10.0, 10000, True, 1000)

# %%
# %pylab inline
pylab.rcParams['figure.figsize'] = (10, 6)
simulated_annealing_convergence5.plot_convergence()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
print(simulated_annealing_convergence5.convergence[-1])
# Out:
# 200.0

# %%
# %pylab inline
pylab.rcParams['figure.figsize'] = (6, 6)
simulated_annealing_convergence5.plot_saved_circuits()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# 522.9938686364042
# 439.81503109532434
# 361.7625612930004
# 379.37080617552226
# 331.01713363324643
# 317.9701262351587
# 283.28163023326033
# 246.8581544580562
# 214.14213562373095
# 200.0
# 200.0

# %%
simulated_annealing_convergence6 = analysis.simulated_annealing_convergence.SimulatedAnnealingConvergence()
simulated_annealing_convergence6.perform_simulation(10, 546854684354354, 10.0, 100000, True, 10000)

# %%
# %pylab inline
pylab.rcParams['figure.figsize'] = (10, 6)
simulated_annealing_convergence6.plot_convergence()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# %pylab inline
pylab.rcParams['figure.figsize'] = (6, 6)
simulated_annealing_convergence6.plot_saved_circuits()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# 4733.699164675562
# 2071.83952846694
# 1995.653497951297
# 1992.7552627153611
# 1744.7976857878898
# 1546.0760144396581
# 1435.52428384636
# 1348.0789138858136
# 1343.234197097462
# 1241.7610142227009
# 1233.8320820345662
